# %% [markdown]
# <a href="https://colab.research.google.com/github/srinath2003/Dev-Assignment/blob/main/assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
op=pd.read_csv("winequalityN.csv")


#op.info
op.describe


op.duplicated().sum()
sb.boxplot(data=op)
sb.violinplot(data=op)
op.plot(kind = 'scatter',x="alcohol",y="quality")
op.plot(kind='hist')

op.plot()

op.plot.bar()


op.plot.barh(stacked=True)



op.plot.area()
